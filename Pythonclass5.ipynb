# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamariyam58/PythonLab1/blob/main/Pythonclass5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#for variable in sequence:
#followed by a statement

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#List=[]
fruits=['apple','banana','cherry']
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
#insert to the list
jungle=["lion","tiger","giraffe","rabbit","wolf"]
print(jungle)
jungle.insert(2,"elephant")
print(jungle)
# Out:
# ['lion', 'tiger', 'giraffe', 'rabbit', 'wolf']
# ['lion', 'tiger', 'elephant', 'giraffe', 'rabbit', 'wolf']

# %%
#print from list by position
jungle=["lion","tiger","giraffe","rabbit","wolf"]
print(jungle[3])
# Out:
# rabbit

# %%
for i in ["a","b","c","d","e"]:
  print(i)
# Out:
# a
# b
# c
# d
# e

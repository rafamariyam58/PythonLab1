# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamariyam58/PythonLab1/blob/main/Pythonclass_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#if_else
temparature=25
if temparature>30:
  print ("it's hot")
else:
  print ("it's cold")
# Out:
# it's cold

# %%
#if_elif_else
score=60
if score>=90:
  print ("Grade A")
elif score>=80:
  print ("Grade B")
elif score>=70:
 print ("Grade C")
elif score>=60:
  print ("Grade D")
else:
  print ("Fail")
# Out:
# Grade D

# %%
#nested_if
age=13
DL_status=False
if age>=18:
  if DL_status:
    print ("you can drive")
  else:
    print ("need license")
else:
  print ("you are young")
# Out:
# you are young

# %%
age=13
M_ticket=True
Food=False
if age>=12:
  if M_ticket:
    if Food:
      print ("Food not allowed")
    else:
      print ("Enter")
  else:
    print ("need ticket")
else:
  print ("you are young")
# Out:
# Enter

# %%
password=12341234
if password==12341234:
  print ("password correct")
elif password==1234:
  print ("double")
else:
  print ("incorrect")
# Out:
# password correct

# %%
age=50
voter_id=True
nationality="indian"
if age>=18:
  if voter_id:
    if nationality=="indian":
      print ("you can vote")
    else:
      print ("not indian")
  else:
    print ("need voter id")
else:
  print ("you are young")
# Out:
# you can vote

# %%
height = 1.72  # meters
weight = 74    # kg
bmi = weight / (height ** 2)

if bmi < 18.5:
    print(f"BMI: {bmi:.1f} - Underweight")
    print("Consider consulting a nutritionist")
elif bmi < 25:
    print(f"BMI: {bmi:.1f} - Normal weight")
    print("Great! Maintain your healthy lifestyle")
elif bmi < 30:
    print(f"BMI: {bmi:.1f} - Overweight")
    print("Consider a balanced diet and exercise")
elif bmi < 35:
    print(f"BMI: {bmi:.1f} - Obese Class I")
    print("Consult a healthcare professional")
elif bmi < 40:
    print(f"BMI: {bmi:.1f} - Obese Class II")
    print("Medical intervention recommended")
else:
    print(f"BMI: {bmi:.1f} - Obese Class III")
    print("Urgent medical consultation required")
# Out:
# BMI: 25.0 - Overweight
# Consider a balanced diet and exercise

# %%
total_bill = 2500.0
no_people = 10
ser_rating = ("excellent")
if ser_rating == "excellent":
    tip_percent = 0.20
    print(f"Tip amount: {total_bill * tip_percent}")
    print(f"Total bill with tip: {total_bill + total_bill*tip_percent}")
    print(f"Amount per person: {total_bill*tip_percent  / no_people}")
elif ser_rating == "good":
    tip_percent = 0.15
    print(f"Tip amount: {total_bill * tip_percent}")
    print(f"Total bill with tip: {total_bill + total_bill*tip_percent}")
    print(f"Amount per person: {total_bill*tip_percent  / no_people}")
elif ser_rating == "average":
    tip_percent = 0.1
    print(f"Tip amount: {total_bill * tip_percent}")
    print(f"Total bill with tip: {total_bill + total_bill*tip_percent}")
    print(f"Amount per person: {total_bill*tip_percent  / no_people}")
elif ser_rating == "poor":
    tip_percent = 0.05
    print(f"Tip amount: {total_bill * tip_percent}")
    print(f"Total bill with tip: {total_bill + total_bill*tip_percent}")
    print(f"Amount per person: {total_bill*tip_percent  / no_people}")
else:
    tip_percent = 0.0
    print(f"Tip amount: {total_bill * tip_percent}")
    print(f"Total bill with tip: {total_bill}")
    print(f"Amount per person: {total_bill / no_people}")
# Out:
# Tip amount: 500.0
# Total bill with tip: 3000.0
# Amount per person: 50.0

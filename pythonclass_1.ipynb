# %% [markdown]
# <a href="https://colab.research.google.com/github/rafamariyam58/PythonLab1/blob/main/pythonclass_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rafa")
# Out:
# rafa

# %%
print ("Name: Rafa Mariyam")
print ("Age: 21")
print ("favourite color: black")
print ("Favourite subject: Python")
print ("Fvourite food: Burger")
print ("no of movies watched: 10")
# Out:
# Name: Rafa Mariyam
# Age: 21
# favourite color: black
# Favourite subject: Python
# Fvourite food: Burger
# no of movies watched: 10

# %%
print("""
This is a paragraph.
You can write multiple lines here.
Python will print all of it exactly as it is.
""")
# Out:
# This is a paragraph.
# You can write multiple lines here.
# Python will print all of it exactly as it is.

# %% [markdown]
# #This is a paragraph.
# You can write multiple lines here.
# Python will print all of it exactly as it is.

# %%
PM=input("Who is the PM of India?")
print(PM)
# Out:
# Who is the PM of India? Narendra Modi
#  Narendra Modi

# %%
color=(input("What is your favourite color?"))
print(color)
# Out:
# What is your favourite color? Red
#  Red

# %%
if "mark=2:
